# %%
import random
import numpy as np
import glob
import pandas as pd

# %%
# Path to import data; can be changed to ml-clean bucket in aws instance
data_path = '../posmo_android/model/ml-clean/'

# Define a list of transport modes used in the plotting
tm_list = [1, 2, 3, 5, 6, 7, 13]

# creating empty lists for storing data
walk = np.array([])
run = np.array([])
bike = np.array([])
tram = np.array([])
bus = np.array([])
train = np.array([])
car = np.array([])

# %%
def reduce_sample_size(data):
    lengths = []
    for mode in data:
        lengths.append(len(mode))
    m = min(lengths)
    walk = np.random.choice(walk, size=m)
    run = np.random.choice(run, size=m)
    bike = np.random.choice(bike, size=m)
    tram = np.random.choice(tram, size=m)
    bus = np.random.choice(bus, size=m)
    train = np.random.choice(train, size=m)
    car = np.random.choice(car, size=m)

# %%
# Selective extraction of data
files = []
for fname in glob.glob(data_path + '*.csv'):
    files.append(fname)

# Iterate through files and save data in .npz file
file_number = 0
for file in files:
    file_number += 1
    if pd.read_csv(file).loc[0, 'label_id'] in tm_list:
        label = pd.read_csv(file).loc[0, 'label_id']
        df = pd.read_csv(file).loc[:, 'speed']
        df = df.dropna()
        #df = df[df > 0.1]
        speed = df.as_matrix()
        speed *= 3.6
        if label == 1:
            walk = np.append(walk, speed)
        elif label == 2:
            run = np.append(run, speed)
        elif label == 3:
            bike = np.append(bike, speed)
        elif label == 5:
            tram = np.append(tram, speed)
        elif label == 6:
            bus = np.append(bus, speed)
        elif label == 7:
            train = np.append(train, speed)
        else:
            car = np.append(car, speed)
        print('File uploaded: {}/{}'.format(file_number, len(files)))
data = [walk, run, bike, tram, bus, train, car]
lengths = []
for mode in data:
    lengths.append(len(mode))
m = min(lengths)
walk = np.random.choice(walk, size=m)
run = np.random.choice(run, size=m)
bike = np.random.choice(bike, size=m)
tram = np.random.choice(tram, size=m)
bus = np.random.choice(bus, size=m)
train = np.random.choice(train, size=m)
car = np.random.choice(car, size=m)
np.savez('data/saved_data', walk=walk, run=run, bike=bike, tram=tram, bus=bus, train=train, car=car)
print('Data saved in: data/saved_data.npz')
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# File uploaded: 1/405
# File uploaded: 2/405
# File uploaded: 3/405
# File uploaded: 4/405
# File uploaded: 5/405
# File uploaded: 6/405
# File uploaded: 7/405
# File uploaded: 8/405
# File uploaded: 9/405
# File uploaded: 10/405
# File uploaded: 11/405
# File uploaded: 14/405
# File uploaded: 15/405
# File uploaded: 16/405
# File uploaded: 17/405
# File uploaded: 19/405
# File uploaded: 20/405
# File uploaded: 21/405
# File uploaded: 22/405
# File uploaded: 23/405
# File uploaded: 24/405
# File uploaded: 25/405
# File uploaded: 26/405
# File uploaded: 27/405
# File uploaded: 28/405
# File uploaded: 29/405
# File uploaded: 30/405
# File uploaded: 32/405
# File uploaded: 33/405
# File uploaded: 34/405
# File uploaded: 35/405
# File uploaded: 36/405
# File uploaded: 37/405
# File uploaded: 38/405
# File uploaded: 39/405
# File uploaded: 40/405
# File uploaded: 41/405
# File uploaded: 42/405
# File uploaded: 43/405
# File uploaded: 44/405
# File uploaded: 45/405
# File uploaded: 47/405
# File uploaded: 48/405
# File uploaded: 49/405
# File uploaded: 50/405
# File uploaded: 51/405
# File uploaded: 52/405
# File uploaded: 53/405
# File uploaded: 54/405
# File uploaded: 55/405
# File uploaded: 56/405
# File uploaded: 57/405
# File uploaded: 58/405
# File uploaded: 59/405
# File uploaded: 60/405
# File uploaded: 61/405
# File uploaded: 62/405
# File uploaded: 63/405
# File uploaded: 64/405
# File uploaded: 65/405
# File uploaded: 66/405
# File uploaded: 67/405
# File uploaded: 68/405
